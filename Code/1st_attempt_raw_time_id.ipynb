# %% [markdown]
# ### Imports

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
from joblib import Parallel, delayed # Run functions in parallel
# import scipy as sc # 
from sklearn.model_selection import KFold
import lightgbm as lgb
import warnings
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import datetime
from enum import Enum
# Out:
# c:\users\george\anaconda3\envs\tensor_cuda\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\george\anaconda3\envs\tensor_cuda\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\users\george\anaconda3\envs\tensor_cuda\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Global variables

# %%
data_dir = '../dataset/optiver-realized-volatility-prediction/'

use_GPU = False

warnings.filterwarnings('ignore')
# pd.set_option('max_columns', 300)

# %% [markdown]
# ### Functional Variables

# %%
buckets_count = 30
max_seconds_in_bucket = 600  # each observation in range 0-600 (seconds)

buckets = np.linspace(0, max_seconds_in_bucket, buckets_count, dtype=int) #  List used for binning (used as a name:lower bound of group) 
buckets = buckets[:-1]


output_dir = 'run_results/'
test_id = '1st_attempt_raw_time_id' + str(buckets_count)
test_dir = output_dir+test_id+"/"

# %% [markdown]
# ### Helper Functions

# %%
# wap of 1st entry in book
def calc_wap1(df):
    wap = (df['bid_price1'] * df['ask_size1'] + df['ask_price1'] * df['bid_size1']) / (df['bid_size1']+ df['ask_size1'])
    return wap

# wap of 2nd entry in book
def calc_wap2(df):
    wap = (df['bid_price2'] * df['bid_size2'] + df['ask_price2'] * df['ask_size2']) / (df['bid_size2'] + df['ask_size2'])
    return wap

# Function to calculate the log of the return
# logb(x / y) = logb(x) - logb(y)
def log_return(series):
    return np.log(series).diff()

def realized_volatility(series):
    return np.sqrt(np.sum(series**2))

def unique_count(series):
    return len(np.unique(series))

# Root mean squared percentage error for early stoping
def rmspe(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

def feval_rmspe(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'RMSPE', rmspe(y_true, y_pred), False

# Create the row_id column to merge data with
def read_main_csvs():
    train = pd.read_csv(data_dir + 'train.csv')
    test = pd.read_csv(data_dir + 'test.csv')
    train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
    test['row_id'] = test['stock_id'].astype(str) + '-' + test['time_id'].astype(str)
    print(f'The training set has {train.shape[0]} rows')
    return train, test

# Create features for order book data (for a given stock file)
def create_bucketed_features(dataframe, aggregate_features_map):
    features = pd.DataFrame()

    for bucket_start_time in buckets:
        # Group into time buckets
        bucketed_features = dataframe[dataframe['seconds_in_bucket']
                                    .between(bucket_start_time, bucket_start_time + buckets[1] - buckets[0])].groupby(['time_id'])                            .agg(aggregate_features_map)
        bucketed_features.columns = ['_'.join(col) for col in bucketed_features.columns]
        bucketed_features = bucketed_features.add_suffix('_' + str(bucket_start_time))
        if bucket_start_time == 0:
            features = bucketed_features
        else:
            features = features.merge(bucketed_features, how = 'outer', left_on = 'time_id', right_on = 'time_id')
    
    return features

def calc_model_importance(model, feature_names=None, importance_type='gain'):
    importance_df = pd.DataFrame(model.feature_importance(importance_type=importance_type),
                                 index=feature_names,
                                 columns=['importance']).sort_values('importance')
    return importance_df

def calc_mean_importance(importance_df_list):
    mean_importance = np.mean(
        np.array([df['importance'].values for df in importance_df_list]), axis=0)
    mean_df = importance_df_list[0].copy()
    mean_df['importance'] = mean_importance
    return mean_df

def plot_importance(importance_fig, filename):
    if not os.path.exists(os.path.dirname(test_dir)):
        try:
            os.makedirs(os.path.dirname(test_dir))
        except:
            print("Could not create dir",filename)
    timestamp = datetime.datetime.now().strftime('%m-%d-%H_%M')
    importance_fig.figure.savefig(test_dir+filename+timestamp+"plot"+".png")
    
    
def save_results_to_file(filename,params,rmspe_score):
    if not os.path.exists(os.path.dirname(test_dir)):
        try:
            os.makedirs(os.path.dirname(test_dir))
        except:
            print("Could not create dir")
    timestamp = datetime.datetime.now().strftime('%m-%d-%H_%M')
    with open(test_dir+filename+timestamp+'.txt', 'w') as f:
        f.write(f'The test RMSPE is {rmspe_score} \n Hyperparams: {params}')

# %% [markdown]
# ### Raw data processing

# %%
# Split into time buckets within a time_id
def group_order_book_in_time_buckets(file_path):
    dataframe = pd.read_parquet(file_path)
        
    aggregate_features_map = {
        'bid_price1': [np.mean],
        'ask_price1': [np.mean],
        
        'bid_price2': [np.mean],
        'ask_price2': [np.mean],
        
        'bid_size1': [np.mean],
        'ask_size1': [np.mean],
        
        'bid_size2': [np.mean],
        'ask_size2': [np.mean],
    }
    
        
    features = create_bucketed_features(dataframe,aggregate_features_map)
    features = features.reset_index(level=0)
    
    stock_id = file_path.split('=')[1]
    features['row_id'] = features['time_id'].apply(lambda x: f'{stock_id}-{x}')
    
    features.drop(['time_id'], axis = 1, inplace = True)
    return features

# Split into time buckets within a time_id
def group_trade_book_in_time_buckets(file_path):
    dataframe = pd.read_parquet(file_path)

    aggregate_features_map = {
        'price':[np.mean],
        'size':[np.mean],
        'order_count':[np.mean],
    }


    features = create_bucketed_features(dataframe,aggregate_features_map)
    features = features.reset_index(level=0)
    
  
    features = features.add_prefix('trade_')
    stock_id = file_path.split('=')[1]
    features['row_id'] = features['trade_time_id'].apply(lambda x: f'{stock_id}-{x}')
    features.drop(['trade_time_id'], axis = 1, inplace = True)
    return features

# %%
def load_stock(stock_id,is_training_set):
    # Train
    if is_training_set:
        order_book_path = f"{data_dir}book_train.parquet/stock_id={str(stock_id)}"
        trade_book_path = f"{data_dir}trade_train.parquet/stock_id={str(stock_id)}"
    # Test
    else:
        order_book_path = f"{data_dir}book_test.parquet/stock_id={str(stock_id)}"
        trade_book_path = f"{data_dir}trade_test.parquet/stock_id={str(stock_id)}"
    # Create order and trade book features and merge them
    processed_order_book = group_order_book_in_time_buckets(order_book_path)
    processed_trade_book = group_trade_book_in_time_buckets(trade_book_path)

    _tmp = pd.merge(processed_order_book, processed_trade_book, on = ['row_id'], how = 'left')
    return _tmp

# %%
# %%time
train, test = read_main_csvs()

# Features engineering & binning for training set
train_stock_ids = train['stock_id'].unique()
dataframes = None
dataframes = Parallel(n_jobs = -1, verbose = 1)(delayed(load_stock)(stock_id,is_training_set=True) for stock_id in train_stock_ids)

train_ = pd.concat(dataframes, ignore_index = True)
train = train.merge(train_, on = ['row_id'], how = 'left')

# Features engineering & binning for test set
test_stock_ids = test['stock_id'].unique()
print(test_stock_ids)
dataframes = None
dataframes = Parallel(n_jobs = -1, verbose = 1)(delayed(load_stock)(stock_id,is_training_set=False) for stock_id in test_stock_ids)

test_ = pd.concat(dataframes, ignore_index = True)
test = test.merge(test_, on = ['row_id'], how = 'left')
# Out:
# The training set has 428932 rows
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:   26.3s finished
# [0]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# CPU times: total: 22.1 s
# Wall time: 46.7 s
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.3s finished

# %%
len(train.index)
# Out:
# 428932

# %%
train.head()
# Out:
#    stock_id  time_id    target row_id  bid_price1_mean_0  ask_price1_mean_0  \
# 0         0        5  0.004136    0-5           1.001422           1.002301
# 1         0       11  0.001445   0-11           0.999473           1.000176
# 2         0       16  0.002168   0-16           0.999662           1.000556
# 3         0       31  0.002195   0-31           0.999815           1.000478
# 4         0       62  0.001747   0-62           0.999744           1.000132
#
#    bid_price2_mean_0  ask_price2_mean_0  bid_size1_mean_0  ask_size1_mean_0  \
# 0           1.001370           1.002397          3.000000        125.692308
# 1           0.999423           1.000376        201.250000        100.000000
# 2           0.999572           1.000763        100.777778         90.666667
# 3           0.999753           1.000540        343.000000        114.000000
# 4           0.999495           1.000225         46.833333          6.500000
#
#    ...  trade_order_count_mean_517  trade_price_mean_537  trade_size_mean_537  \
# 0  ...                         1.0              1.003008            43.250000
# 1  ...                         1.0              1.000818            12.333333
# 2  ...                         6.0              0.997542           246.000000
# 3  ...                         NaN              0.998011            59.000000
# 4  ...                         NaN              0.999417             1.000000
#
#    trade_order_count_mean_537  trade_price_mean_558  trade_size_mean_558  \
# 0                    2.500000              1.002953                250.0
# 1                    1.666667              1.000627                206.0
# 2                    3.000000                   NaN                  NaN
# 3                    2.000000              0.997972                450.0
# 4                    1.000000                   NaN                  NaN
#
#    trade_order_count_mean_558  trade_price_mean_579  trade_size_mean_579  \
# 0                         3.5              1.003562                 17.0
# 1                         6.0                   NaN                  NaN
# 2                         NaN              0.997535                105.5
# 3                         8.0                   NaN                  NaN
# 4                         NaN              0.999749                 34.0
#
#    trade_order_count_mean_579
# 0                         2.5
# 1                         NaN
# 2                         2.5
# 3                         NaN
# 4                        10.0
#
# [5 rows x 323 columns]

# %%
test.head()
# Out:
#    stock_id  time_id row_id  bid_price1_mean_0  ask_price1_mean_0  \
# 0         0        4    0-4           1.000049           1.000606
# 1         0       32   0-32                NaN                NaN
# 2         0       34   0-34                NaN                NaN
#
#    bid_price2_mean_0  ask_price2_mean_0  bid_size1_mean_0  ask_size1_mean_0  \
# 0           0.999656           1.000721        157.333333         73.333333
# 1                NaN                NaN               NaN               NaN
# 2                NaN                NaN               NaN               NaN
#
#    bid_size2_mean_0  ...  trade_order_count_mean_517  trade_price_mean_537  \
# 0        100.333333  ...                         NaN                   NaN
# 1               NaN  ...                         NaN                   NaN
# 2               NaN  ...                         NaN                   NaN
#
#    trade_size_mean_537  trade_order_count_mean_537  trade_price_mean_558  \
# 0                  NaN                         NaN                   NaN
# 1                  NaN                         NaN                   NaN
# 2                  NaN                         NaN                   NaN
#
#    trade_size_mean_558  trade_order_count_mean_558  trade_price_mean_579  \
# 0                  NaN                         NaN                   NaN
# 1                  NaN                         NaN                   NaN
# 2                  NaN                         NaN                   NaN
#
#    trade_size_mean_579  trade_order_count_mean_579
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
#
# [3 rows x 322 columns]

# %%
train.columns
# Out:
# Index(['stock_id', 'time_id', 'target', 'row_id', 'bid_price1_mean_0',
#        'ask_price1_mean_0', 'bid_price2_mean_0', 'ask_price2_mean_0',
#        'bid_size1_mean_0', 'ask_size1_mean_0',
#        ...
#        'trade_order_count_mean_517', 'trade_price_mean_537',
#        'trade_size_mean_537', 'trade_order_count_mean_537',
#        'trade_price_mean_558', 'trade_size_mean_558',
#        'trade_order_count_mean_558', 'trade_price_mean_579',
#        'trade_size_mean_579', 'trade_order_count_mean_579'],
#       dtype='object', length=323)

# %%
# train = train.drop(['time_id'], axis = 1)
# test = test.drop(['time_id'], axis = 1)

# %%
def train_and_evaluate(train, test):
    # Hyperparammeters (just basic)
    
    hyperparameters = {
        'objective': 'rmse',  
        'boosting_type': 'gbdt',
        #'boosting_type': 'dart',          # Try to solve over-specialization problem in gbdt
        #'boosting_type': 'goss',          # Goss provides a new sampling method for GBDT by separating those instances with larger gradients.
        'num_iterations': 5678,            # Num_iterations specifies the number of boosting iterations (trees to build). The more trees you build the more accurate your model can be at the cost of:
        'n_estimators': 10000,             # controls the number of decision trees 
        'min_data_in_leaf': 9,
        'max_bin': 75,                     # If you define max_bin 255 that means we can have a maximum of 255 unique values per feature. Then Small max_bin causes faster speed and large value improves accuracy.
        'num_leaves': 27,
        'max_depth': 9,                    # This parameter control max depth of each trained tree and will have impact on:       The best value for the num_leaves parameter     Model Performance Training Time  Pay attention If you use a large value of max_depth, your model will likely be over fit  to the train set
        'n_jobs': -1,
        'learning_rate': 0.095,            # learning_rate > 0.0 Typical: 0.05.
        'feature_fraction': 0.9,           # or sub_feature deals with column sampling, LightGBM will randomly select a subset of features on each iteration (tree)
        'bagging_fraction': 0.9,           # you can specify the percentage of rows used per tree building iteration.
        'verbose': -1,
    }
    
    if use_GPU:
        hyperparameters.update(
            {'device' : 'gpu',
            'gpu_platform_id' : 0,
            'gpu_device_id' : 0,}
        )
   
    # We need to drop row_id as it contains info from both time_id and stock_id and time id should be out of the features | should only be used in predictions
    x = train.drop(['row_id', 'target'], axis = 1)
    y = train['target']
    x_test = test.drop(['row_id'], axis = 1)

    x['stock_id'] = x['stock_id'].astype(int)
    x_test['stock_id'] = x_test['stock_id'].astype(int)

    x['time_id'] = x['time_id'].astype(int)
    x_test['time_id'] = x_test['time_id'].astype(int)
    
    test_predictions = np.zeros(x_test.shape[0])
    
    # Create out of folds array
    oof_predictions = np.zeros(x.shape[0])

    
    kfold = KFold(n_splits = 5, random_state = 66, shuffle = True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(x)):
        print(f'Training fold {fold + 1}')
        x_train, x_val = x.iloc[trn_ind], x.iloc[val_ind]
        y_train, y_val = y.iloc[trn_ind], y.iloc[val_ind]
        # Root mean squared percentage error weights
        train_weights = 1 / np.square(y_train)
        val_weights = 1 / np.square(y_val)
#         train_dataset = lgb.Dataset(x_train, y_train, weight = train_weights, categorical_feature = ['stock_id'])
#         val_dataset = lgb.Dataset(x_val, y_val, weight = val_weights, categorical_feature = ['stock_id'])
        train_dataset = lgb.Dataset(x_train, y_train, weight = train_weights, categorical_feature = ['stock_id', 'time_id'])
        val_dataset = lgb.Dataset(x_val, y_val, weight = val_weights, categorical_feature = ['stock_id', 'time_id'])
        model = lgb.train(params = hyperparameters, 
                          train_set = train_dataset, 
                          valid_sets = [train_dataset, val_dataset], 
                          num_boost_round = 10000, 
                          early_stopping_rounds = 50, 
                          verbose_eval = 50,
                          feval = feval_rmspe)
        # Add predictions to the out of folds array
        oof_predictions[val_ind] = model.predict(x_val)
        # Predict the test set
        test_predictions += model.predict(x_test) / 5
    
    importance_plot = lgb.plot_importance(model,max_num_features=7,figsize=(32,15))
    plot_importance(importance_plot, "feature_importance_plot")
    rmspe_score = rmspe(y, oof_predictions)
    print(f'The out of folds RMSPE is {rmspe_score}')

    return test_predictions

# %%
# %%time
# Traing and evaluating
test_predictions = train_and_evaluate(train, test)
# Out:
# Training fold 1
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 0.000625931	training's RMSPE: 0.289904	valid_1's rmse: 0.000652474	valid_1's RMSPE: 0.301074
# [100]	training's rmse: 0.00055316	training's RMSPE: 0.2562	valid_1's rmse: 0.000589181	valid_1's RMSPE: 0.271869
# [150]	training's rmse: 0.000510901	training's RMSPE: 0.236627	valid_1's rmse: 0.000556847	valid_1's RMSPE: 0.256948
# [200]	training's rmse: 0.000481965	training's RMSPE: 0.223225	valid_1's rmse: 0.000539333	valid_1's RMSPE: 0.248867
# [250]	training's rmse: 0.000461641	training's RMSPE: 0.213812	valid_1's rmse: 0.000529314	valid_1's RMSPE: 0.244244
# [300]	training's rmse: 0.000446537	training's RMSPE: 0.206817	valid_1's rmse: 0.000523033	valid_1's RMSPE: 0.241346
# [350]	training's rmse: 0.000434413	training's RMSPE: 0.201201	valid_1's rmse: 0.000518856	valid_1's RMSPE: 0.239418
# [400]	training's rmse: 0.000424504	training's RMSPE: 0.196612	valid_1's rmse: 0.000515903	valid_1's RMSPE: 0.238056
# [450]	training's rmse: 0.000415877	training's RMSPE: 0.192616	valid_1's rmse: 0.000513631	valid_1's RMSPE: 0.237007
# [500]	training's rmse: 0.000407911	training's RMSPE: 0.188927	valid_1's rmse: 0.000512437	valid_1's RMSPE: 0.236456
# [550]	training's rmse: 0.00040088	training's RMSPE: 0.18567	valid_1's rmse: 0.000511124	valid_1's RMSPE: 0.23585
# [600]	training's rmse: 0.000394421	training's RMSPE: 0.182679	valid_1's rmse: 0.000509904	valid_1's RMSPE: 0.235287
# [650]	training's rmse: 0.000388555	training's RMSPE: 0.179962	valid_1's rmse: 0.00050948	valid_1's RMSPE: 0.235092
# [700]	training's rmse: 0.000382954	training's RMSPE: 0.177368	valid_1's rmse: 0.000508489	valid_1's RMSPE: 0.234635
# [750]	training's rmse: 0.000377805	training's RMSPE: 0.174983	valid_1's rmse: 0.000507732	valid_1's RMSPE: 0.234285
# [800]	training's rmse: 0.000372653	training's RMSPE: 0.172596	valid_1's rmse: 0.000507418	valid_1's RMSPE: 0.23414
# [850]	training's rmse: 0.000368057	training's RMSPE: 0.170468	valid_1's rmse: 0.000506958	valid_1's RMSPE: 0.233928
# [900]	training's rmse: 0.000363634	training's RMSPE: 0.16842	valid_1's rmse: 0.00050645	valid_1's RMSPE: 0.233694
# [950]	training's rmse: 0.000359636	training's RMSPE: 0.166568	valid_1's rmse: 0.000506312	valid_1's RMSPE: 0.23363
# [1000]	training's rmse: 0.000355391	training's RMSPE: 0.164602	valid_1's rmse: 0.000506109	valid_1's RMSPE: 0.233536
# Early stopping, best iteration is:
# [994]	training's rmse: 0.000355894	training's RMSPE: 0.164835	valid_1's rmse: 0.00050601	valid_1's RMSPE: 0.233491
# Training fold 2
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 0.000627638	training's RMSPE: 0.290325	valid_1's rmse: 0.0006554	valid_1's RMSPE: 0.30397
# [100]	training's rmse: 0.000557313	training's RMSPE: 0.257795	valid_1's rmse: 0.000592252	valid_1's RMSPE: 0.274682
# [150]	training's rmse: 0.000511176	training's RMSPE: 0.236453	valid_1's rmse: 0.000554944	valid_1's RMSPE: 0.257379
# [200]	training's rmse: 0.00048185	training's RMSPE: 0.222888	valid_1's rmse: 0.00053585	valid_1's RMSPE: 0.248523
# [250]	training's rmse: 0.000460748	training's RMSPE: 0.213127	valid_1's rmse: 0.000524412	valid_1's RMSPE: 0.243218
# [300]	training's rmse: 0.000445293	training's RMSPE: 0.205978	valid_1's rmse: 0.000517734	valid_1's RMSPE: 0.240122
# [350]	training's rmse: 0.000433153	training's RMSPE: 0.200363	valid_1's rmse: 0.000513163	valid_1's RMSPE: 0.238001
# [400]	training's rmse: 0.000422953	training's RMSPE: 0.195644	valid_1's rmse: 0.000509481	valid_1's RMSPE: 0.236294
# [450]	training's rmse: 0.000413863	training's RMSPE: 0.19144	valid_1's rmse: 0.00050705	valid_1's RMSPE: 0.235166
# [500]	training's rmse: 0.000406619	training's RMSPE: 0.188089	valid_1's rmse: 0.000505665	valid_1's RMSPE: 0.234524
# [550]	training's rmse: 0.000399517	training's RMSPE: 0.184804	valid_1's rmse: 0.000504247	valid_1's RMSPE: 0.233866
# [600]	training's rmse: 0.00039294	training's RMSPE: 0.181761	valid_1's rmse: 0.000503118	valid_1's RMSPE: 0.233343
# [650]	training's rmse: 0.000387245	training's RMSPE: 0.179127	valid_1's rmse: 0.000502217	valid_1's RMSPE: 0.232925
# [700]	training's rmse: 0.000381452	training's RMSPE: 0.176447	valid_1's rmse: 0.000501558	valid_1's RMSPE: 0.232619
# [750]	training's rmse: 0.000376642	training's RMSPE: 0.174222	valid_1's rmse: 0.00050094	valid_1's RMSPE: 0.232332
# [800]	training's rmse: 0.000371956	training's RMSPE: 0.172055	valid_1's rmse: 0.000500091	valid_1's RMSPE: 0.231939
# [850]	training's rmse: 0.000367192	training's RMSPE: 0.169851	valid_1's rmse: 0.000499332	valid_1's RMSPE: 0.231587
# [900]	training's rmse: 0.000362491	training's RMSPE: 0.167676	valid_1's rmse: 0.000499096	valid_1's RMSPE: 0.231477
# [950]	training's rmse: 0.000358652	training's RMSPE: 0.165901	valid_1's rmse: 0.00049895	valid_1's RMSPE: 0.23141
# Early stopping, best iteration is:
# [925]	training's rmse: 0.000360582	training's RMSPE: 0.166793	valid_1's rmse: 0.000498879	valid_1's RMSPE: 0.231377
# Training fold 3
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 0.000628865	training's RMSPE: 0.29107	valid_1's rmse: 0.000651046	valid_1's RMSPE: 0.301216
# [100]	training's rmse: 0.000557051	training's RMSPE: 0.257831	valid_1's rmse: 0.000586682	valid_1's RMSPE: 0.271437
# [150]	training's rmse: 0.000512705	training's RMSPE: 0.237306	valid_1's rmse: 0.000552915	valid_1's RMSPE: 0.255814
# [200]	training's rmse: 0.00048369	training's RMSPE: 0.223876	valid_1's rmse: 0.000533818	valid_1's RMSPE: 0.246978
# [250]	training's rmse: 0.000463387	training's RMSPE: 0.214479	valid_1's rmse: 0.000523272	valid_1's RMSPE: 0.242099
# [300]	training's rmse: 0.000448569	training's RMSPE: 0.20762	valid_1's rmse: 0.000516734	valid_1's RMSPE: 0.239074
# [350]	training's rmse: 0.000436184	training's RMSPE: 0.201888	valid_1's rmse: 0.000512113	valid_1's RMSPE: 0.236936
# [400]	training's rmse: 0.000425679	training's RMSPE: 0.197025	valid_1's rmse: 0.000509072	valid_1's RMSPE: 0.235529
# [450]	training's rmse: 0.000417026	training's RMSPE: 0.19302	valid_1's rmse: 0.000506795	valid_1's RMSPE: 0.234475
# [500]	training's rmse: 0.000409656	training's RMSPE: 0.189609	valid_1's rmse: 0.000504924	valid_1's RMSPE: 0.23361
# [550]	training's rmse: 0.000402695	training's RMSPE: 0.186388	valid_1's rmse: 0.000503713	valid_1's RMSPE: 0.23305
# [600]	training's rmse: 0.000396179	training's RMSPE: 0.183371	valid_1's rmse: 0.000502469	valid_1's RMSPE: 0.232474
# [650]	training's rmse: 0.000390457	training's RMSPE: 0.180723	valid_1's rmse: 0.000501591	valid_1's RMSPE: 0.232068
# [700]	training's rmse: 0.00038493	training's RMSPE: 0.178165	valid_1's rmse: 0.000500808	valid_1's RMSPE: 0.231706
# [750]	training's rmse: 0.000379777	training's RMSPE: 0.17578	valid_1's rmse: 0.000500038	valid_1's RMSPE: 0.231349
# [800]	training's rmse: 0.000375106	training's RMSPE: 0.173618	valid_1's rmse: 0.000499286	valid_1's RMSPE: 0.231002
# [850]	training's rmse: 0.000370554	training's RMSPE: 0.171511	valid_1's rmse: 0.000499365	valid_1's RMSPE: 0.231038
# Early stopping, best iteration is:
# [820]	training's rmse: 0.00037328	training's RMSPE: 0.172773	valid_1's rmse: 0.000499029	valid_1's RMSPE: 0.230882
# Training fold 4
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 0.000626359	training's RMSPE: 0.289447	valid_1's rmse: 0.000664321	valid_1's RMSPE: 0.309315
# [100]	training's rmse: 0.000556398	training's RMSPE: 0.257117	valid_1's rmse: 0.000603434	valid_1's RMSPE: 0.280966
# [150]	training's rmse: 0.000513425	training's RMSPE: 0.237259	valid_1's rmse: 0.000571614	valid_1's RMSPE: 0.26615
# [200]	training's rmse: 0.000485342	training's RMSPE: 0.224282	valid_1's rmse: 0.000554573	valid_1's RMSPE: 0.258216
# [250]	training's rmse: 0.000463066	training's RMSPE: 0.213988	valid_1's rmse: 0.000546313	valid_1's RMSPE: 0.25437
# [300]	training's rmse: 0.000447453	training's RMSPE: 0.206773	valid_1's rmse: 0.000539301	valid_1's RMSPE: 0.251105
# [350]	training's rmse: 0.000435354	training's RMSPE: 0.201182	valid_1's rmse: 0.00053507	valid_1's RMSPE: 0.249135
# [400]	training's rmse: 0.000425221	training's RMSPE: 0.196499	valid_1's rmse: 0.000532023	valid_1's RMSPE: 0.247716
# [450]	training's rmse: 0.000416415	training's RMSPE: 0.19243	valid_1's rmse: 0.000530493	valid_1's RMSPE: 0.247003
# [500]	training's rmse: 0.000408753	training's RMSPE: 0.188889	valid_1's rmse: 0.000528676	valid_1's RMSPE: 0.246157
# [550]	training's rmse: 0.000401801	training's RMSPE: 0.185676	valid_1's rmse: 0.000528121	valid_1's RMSPE: 0.245899
# [600]	training's rmse: 0.00039537	training's RMSPE: 0.182705	valid_1's rmse: 0.000527462	valid_1's RMSPE: 0.245592
# [650]	training's rmse: 0.000389824	training's RMSPE: 0.180142	valid_1's rmse: 0.000526604	valid_1's RMSPE: 0.245193
# [700]	training's rmse: 0.000384448	training's RMSPE: 0.177658	valid_1's rmse: 0.000525922	valid_1's RMSPE: 0.244875
# [750]	training's rmse: 0.000379319	training's RMSPE: 0.175287	valid_1's rmse: 0.000525017	valid_1's RMSPE: 0.244454
# [800]	training's rmse: 0.000374509	training's RMSPE: 0.173065	valid_1's rmse: 0.000525019	valid_1's RMSPE: 0.244455
# Early stopping, best iteration is:
# [779]	training's rmse: 0.000376501	training's RMSPE: 0.173985	valid_1's rmse: 0.000524741	valid_1's RMSPE: 0.244325
# Training fold 5
# Training until validation scores don't improve for 50 rounds
# [50]	training's rmse: 0.000627055	training's RMSPE: 0.290563	valid_1's rmse: 0.000662219	valid_1's RMSPE: 0.304981
# [100]	training's rmse: 0.000557504	training's RMSPE: 0.258335	valid_1's rmse: 0.000600046	valid_1's RMSPE: 0.276347
# [150]	training's rmse: 0.000513279	training's RMSPE: 0.237842	valid_1's rmse: 0.000565482	valid_1's RMSPE: 0.260429
# [200]	training's rmse: 0.000484109	training's RMSPE: 0.224325	valid_1's rmse: 0.000546362	valid_1's RMSPE: 0.251623
# [250]	training's rmse: 0.000463268	training's RMSPE: 0.214668	valid_1's rmse: 0.000536389	valid_1's RMSPE: 0.247031
# [300]	training's rmse: 0.000447348	training's RMSPE: 0.207291	valid_1's rmse: 0.000531199	valid_1's RMSPE: 0.24464
# [350]	training's rmse: 0.000434939	training's RMSPE: 0.201541	valid_1's rmse: 0.000527139	valid_1's RMSPE: 0.242771
# [400]	training's rmse: 0.000424833	training's RMSPE: 0.196858	valid_1's rmse: 0.000524578	valid_1's RMSPE: 0.241591
# [450]	training's rmse: 0.000416196	training's RMSPE: 0.192856	valid_1's rmse: 0.000523037	valid_1's RMSPE: 0.240881
# [500]	training's rmse: 0.000408267	training's RMSPE: 0.189182	valid_1's rmse: 0.000521501	valid_1's RMSPE: 0.240174
# [550]	training's rmse: 0.000401127	training's RMSPE: 0.185874	valid_1's rmse: 0.000520235	valid_1's RMSPE: 0.239591
# [600]	training's rmse: 0.000394797	training's RMSPE: 0.18294	valid_1's rmse: 0.000519013	valid_1's RMSPE: 0.239028
# [650]	training's rmse: 0.000388969	training's RMSPE: 0.18024	valid_1's rmse: 0.00051789	valid_1's RMSPE: 0.238511
# [700]	training's rmse: 0.000383663	training's RMSPE: 0.177781	valid_1's rmse: 0.000517205	valid_1's RMSPE: 0.238195
# [750]	training's rmse: 0.000378563	training's RMSPE: 0.175418	valid_1's rmse: 0.00051654	valid_1's RMSPE: 0.237889
# [800]	training's rmse: 0.000373769	training's RMSPE: 0.173196	valid_1's rmse: 0.000515974	valid_1's RMSPE: 0.237629
# [850]	training's rmse: 0.000369238	training's RMSPE: 0.171097	valid_1's rmse: 0.000515514	valid_1's RMSPE: 0.237417
# [900]	training's rmse: 0.000365102	training's RMSPE: 0.16918	valid_1's rmse: 0.000515272	valid_1's RMSPE: 0.237305
# [950]	training's rmse: 0.000360829	training's RMSPE: 0.1672	valid_1's rmse: 0.000516799	valid_1's RMSPE: 0.238009
# Early stopping, best iteration is:
# [931]	training's rmse: 0.000362329	training's RMSPE: 0.167896	valid_1's rmse: 0.000514937	valid_1's RMSPE: 0.237151
# The out of folds RMSPE is 0.2354974444382633
# CPU times: total: 49min 11s
# Wall time: 4min 24s

# %%
# Save test predictions for submission
test['target'] = test_predictions
test[['row_id', 'target']].to_csv('submission.csv',index = False)
